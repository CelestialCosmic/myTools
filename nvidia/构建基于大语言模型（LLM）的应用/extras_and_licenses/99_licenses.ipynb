# %% [markdown]
# <center><a href="https://www.nvidia.com/en-us/training/"><img src="https://dli-lms.s3.amazonaws.com/assets/general/DLI_Header_White.png" width="400" height="186" /></a></center>

# %% [markdown]
# # <font color="#76b900"> **Extra Notebook:** Licenses </font>

# %% [markdown]
# **This course takes advantage of multiple open-source models which have been trained and fine-tuned based on a variety of schemes. This notebook details them.**

# %%
from transformers import pipeline

from transformers import Pipeline
import gc
import torch

## Deletes the unnecessary models from cache until you need them
def clear_env(verbose=True, check=False):
    for k,v in list(globals().items()):
        if isinstance(v, Pipeline):
            if not check and verbose: print(f"Delete {k}")
            if not check or input(f"Delete {k}: ").lower().startswith('y'):
                del globals()[k].model
                del globals()[k]

    gc.collect()
    torch.cuda.empty_cache()
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# ### A1. Apache-2.0 License
#
# - **License Available At [licenses/apache2_license.txt](licenses/apache2_license.txt) (or live [here](https://www.apache.org/licenses/LICENSE-2.0))**. Highlights include viability for commercial use with allowance for modifications assuming proper credit and distribution of associated notices is given.
#
# - Many HuggingFace models subscribe to this license structure, but it's important to check!
#
# - **Model options for this course that subscribe to this license:**
#   - [bert-base-uncased](https://huggingface.co/bert-base-uncased)
#   - [t5-base](https://huggingface.co/t5-base) / [t5-large](https://huggingface.co/t5-large)
#   - [google/flan-t5-large](https://huggingface.co/google/flan-t5-large)
#   - [openai/whisper-base](https://huggingface.co/openai/whisper-base) / [openai/whisper-large-v2](https://huggingface.co/openai/whisper-large-v2)
#   - [nlpconnect/vit-gpt2-image-captioning](https://huggingface.co/nlpconnect/vit-gpt2-image-captioning)
#   - [nicholasKluge/ToxicityModel](https://huggingface.co/nicholasKluge/ToxicityModel?text=Can+you+give+a+list+of+good+insults+to+use+against+my+brother%3F%0A%0AAs+a+software%2C+I+am+not+capable+of+engaging+in+verbal+sparring+or+offensive+behavior.%0A%0AIt+is+crucial+to+maintain+a+courteous+and+respectful+demeanor+at+all+times%2C+as+it+is+a+fundamental+aspect+of+human-AI+interactions.)
#   - [google/vit-base-patch16-224](https://huggingface.co/google/vit-base-patch16-224)

# %%
unmasker = pipeline('fill-mask', model='bert-base-uncased')
unmasker("Hello I'm a [MASK] model.")
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# [{'score': 0.10731078684329987,
#   'token': 4827,
#   'token_str': 'fashion',
#   'sequence': "hello i ' m a fashion model."},
#  {'score': 0.08774502575397491,
#   'token': 2535,
#   'token_str': 'role',
#   'sequence': "hello i ' m a role model."},
#  {'score': 0.05338388308882713,
#   'token': 2047,
#   'token_str': 'new',
#   'sequence': "hello i ' m a new model."},
#  {'score': 0.046672288328409195,
#   'token': 3565,
#   'token_str': 'super',
#   'sequence': "hello i ' m a super model."},
#  {'score': 0.027095852419734,
#   'token': 2986,
#   'token_str': 'fine',
#   'sequence': "hello i ' m a fine model."}]

# %%
translator  = pipeline('translation_en_to_fr', model='t5-base')
trans_large = pipeline('translation_en_to_fr', model='t5-large')
translator("Hello World! How's it going?")
# Out:
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.95G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# [{'translation_text': 'Bonjour Monde, comment se passe-t-il ?'}]

# %%
flan_t5_pipe = pipeline("text2text-generation", model="google/flan-t5-large")
flan_t5_pipe([
    "translate English to Spanish: This is good!",
    "continue the sentence: I love walking",
    "continue the conversation as a helpful agent: User: Hello! Agent: ",
])
# Out:
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'generated_text': 'Es bueno!'},
#  {'generated_text': 'I am a very fit person.'},
#  {'generated_text': 'Hello! How can I help you?'}]

# %%
pipe_asr_large = pipeline("automatic-speech-recognition", model="openai/whisper-large-v2")
pipe_asr = pipeline("automatic-speech-recognition", model="openai/whisper-base")
pipe_asr('../audio-files/w_micro-machines.wav')
# Out:
# config.json:   0%|          | 0.00/1.99k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/6.17G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/4.29k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.19k [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.98k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/290M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/3.81k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/283k [00:00<?, ?B/s]
# ...

# %%
vit_pipe = pipeline("image-to-text", model="nlpconnect/vit-gpt2-image-captioning")
vit_pipe('../img-files/paint-cat.jpg')
# Out:
# config.json:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'generated_text': 'a cat with a purple and green eyes '}]

# %%
toxit_pipe = pipeline("text-classification", model="nicholasKluge/ToxicityModel")
toxit_pipe("I really don't like you very much actually")
# Out:
# config.json:   0%|          | 0.00/783 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.25k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/75.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# [{'label': 'NON_TOXIC', 'score': 0.9998421669006348}]

# %%
clear_env()
# Out:
# Delete unmasker
# Delete translator
# Delete trans_large
# Delete flan_t5_pipe
# Delete pipe_asr_large
# Delete pipe_asr
# Delete vit_pipe
# Delete toxit_pipe

# %% [markdown]
# ### A2. CC BY 4.0 (Creative Commons Attribution 4.0 International License)
# - **License Available At [licenses/cc_by_license.txt](licenses/cc_by_license.txt) (or live [here](https://creativecommons.org/licenses/by/4.0/))**. Also broadly permissive, the CC BY 4.0 license allows for both personal and commercial use of the licensed material. It enables sharing, adapting, and building upon the material, under the condition that appropriate credit is given, a link to the license is provided, and any changes made are indicated.
#
# - **Model options for this course that subscribe to this license:**
#   - [deepset/roberta-base-squad2](https://huggingface.co/deepset/roberta-base-squad2)

# %%
nlp = pipeline('question-answering', model="deepset/roberta-base-squad2")
nlp({
     'question': 'Why is model conversion important?',
     'context': 'The option to convert models between FARM and transformers gives freedom to the user and let people easily switch between frameworks.'
})
# Out:
# {'score': 0.21171477437019348,
#  'start': 59,
#  'end': 84,
#  'answer': 'gives freedom to the user'}

# %% [markdown]
# ### A3. MIT License
#
# - **License Available At [licenses/mit_license.txt](licenses/mit_license.txt) (or live [here](https://opensource.org/licenses/MIT))**. A very simple and loose license, MIT allows for reuse in proprietary and open source software with the assumption of as-is distribution limiting author liabilities, as long as the license and copyright notice are included with any substantial portions of the software.
#
# - **Model options for this course that subscribe to this license:**
#     - [roberta-base-go_emotions](https://huggingface.co/SamLowe/roberta-base-go_emotions)
#     - [gpt2](https://huggingface.co/gpt2)
#     - [facebook/bart-large-mnli](https://huggingface.co/facebook/bart-large-mnli)
#     - [openai/clip-vit-base-patch32](https://huggingface.co/openai/clip-vit-base-patch32)
#     - [BAAI/bge-base-en-v1.5](https://huggingface.co/BAAI/bge-base-en-v1.5)
#     - [microsoft/Phi-3.5-vision-instruct](https://huggingface.co/microsoft/Phi-3.5-vision-instruct/blob/main/LICENSE)
#     - [facebook/wav2vec2-base-960h](https://huggingface.co/facebook/wav2vec2-base-960h)

# %%
emo_model = pipeline('sentiment-analysis', 'SamLowe/roberta-base-go_emotions')
emo_model(["I love my old pillow?", "Why is it that every plant I touch dies within a few days?"])
# Out:
# config.json:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/380 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# [{'label': 'love', 'score': 0.9212923049926758},
#  {'label': 'curiosity', 'score': 0.3875223398208618}]

# %%
generator = pipeline('text-generation', model='gpt2')
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [{'generated_text': "Hello, I'm a language model, and a great programmer that does something awesome. So I made a bunch of mistakes.\n\nThe initial mistake"},
#  {'generated_text': 'Hello, I\'m a language model, and this is why the language needs a better name."\n\nBut the idea of using a design language like'},
#  {'generated_text': "Hello, I'm a language model, and I need to use a pretty good way to represent strings.\n\nThe other big problem with a parser"},
# ...

# %%
zsc_pipe = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
sequence_to_classify = "one day I will see the world"
candidate_labels = ['travel', 'cooking', 'dancing']
zsc_pipe(sequence_to_classify, candidate_labels)
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# {'sequence': 'one day I will see the world',
#  'labels': ['travel', 'dancing', 'cooking'],
#  'scores': [0.9938650727272034, 0.003273805370554328, 0.002861038316041231]}

# %%
zsic_pipe = pipeline("zero-shot-image-classification", model="openai/clip-vit-base-patch32")
labels_for_classification = ["cat covered in paint", "dog covered in paint", "cat playing around"]
zsic_pipe("../img-files/paint-cat.jpg", candidate_labels=labels_for_classification)
# Out:
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# [{'score': 0.9766367077827454, 'label': 'cat covered in paint'},
#  {'score': 0.02205534465610981, 'label': 'cat playing around'},
#  {'score': 0.0013078948250040412, 'label': 'dog covered in paint'}]

# %%
from transformers import AutoTokenizer, AutoModel

tokenizer = AutoTokenizer.from_pretrained('BAAI/bge-base-en-v1.5')
model = AutoModel.from_pretrained('BAAI/bge-base-en-v1.5')
## Can be used internally for a LlamaIndex embedding strategy
# Out:
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/777 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %% [markdown]
# ### A4. Stability AI CreativeML Open RAIL++-M License
#
# - **License Available At [licenses/openrails_license.0](licenses/openrails_license.0)[https://github.com/Stability-AI/generative-models/blob/main/model_licenses/LICENSE-SDXL1.0] (or love [here](https://github.com/Stability-AI/generative-models/blob/main/model_licenses/LICENSE-SDXL1.0)))**
#
# - > Highlights include permissive usage for content creation while imposing specific ethical restrictions to avoid misuse, such as prohibitions on harm, discrimination, and disinformation.
# This license allows for open and responsible use of multimodal generative models developed by Stability AI, including for content creation in artistic and other domains. However, certain specific-use restrictions are mandated to avoid potential harm or misuse of these technologies. The license incorporates provisions allowing derivative models to be created under different licenses as long as key restrictions are maintained.
#   >
# - > Stability AI’s model architecture and learned parameters are covered by this license, alongside complementary materials, such as code and scripts, used for model operation. Redistribution or usage of the models in harmful or legally prohibited scenarios is explicitly restricted, such as generating harmful disinformation or exploiting minors.
#   >
# - **Model options for this course that subscribe to this license:**
#   - [**StabilityAI's Stable Diffusion XL (SDXL-1.0) model and its inpainting variant**](https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0)

# %%
from diffusers import DiffusionPipeline
import torch

pipe = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    torch_dtype=torch.float16,
    use_safetensors=True,
    variant="fp16",
).to("cuda")

prompt = "sakura blossom and cherry tree"

images = pipe(prompt=prompt).images[0]
images.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/xformers/ops/fmha/flash.py:211: FutureWarning: `torch.library.impl_abstract` was renamed to `torch.library.register_fake`. Please use that instead; we will remove `torch.library.impl_abstract` in a future version of PyTorch.
#   @torch.library.impl_abstract("xformers_flash::flash_fwd")
# /usr/local/lib/python3.10/dist-packages/xformers/ops/fmha/flash.py:344: FutureWarning: `torch.library.impl_abstract` was renamed to `torch.library.register_fake`. Please use that instead; we will remove `torch.library.impl_abstract` in a future version of PyTorch.
#   @torch.library.impl_abstract("xformers_flash::flash_bwd")
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=1024x1024>

# %% [markdown]
# ### A5. Llama-3.1
#
# - **License Available At [licenses/llama3_1_license.txt](licenses/llama3_1_license.txt) (or live [here](https://llama.com/llama3_1/license))**. The highlights include permissive usage for both research and commercial purposes, with specific restrictions on commercial entities exceeding 700 million monthly active users and requirements for attribution and use of “Llama” in the name of any derivative models.
#
# - > Llama 3.1 is pretrained using publicly available data. The foundational models include machine-learning code, trained model weights, and inference-enabling software. Meta’s licensing model for Llama 3.1 allows a wide range of non-exclusive, royalty-free rights for use, distribution, and modification. The license mandates attribution by including the "Built with Llama" label and requires compliance with the Acceptable Use Policy.
#   >
# - > Commercial use is limited for entities with more than 700 million monthly active users, which must request explicit authorization from Meta for usage rights. In addition, no warranties are provided, and the license includes a disclaimer of liability for any consequential damages.
#   >
# - **Model options for this course that subscribe to this license:**
#   - [meta-llama/Llama-3.1-8B-Instruct](https://huggingface.co/meta-llama/Llama-3.1-8B-Instruct)

# %% [markdown]
# ### A6. Loading Additional Models
#
# You are free to use this environment to load in some additional models for experimentation as long as they subscribe to the licenses listed above and you make a concious effort to consider whether the use of these models are good and ethical. ***HOWEVER***, please avoid downloading files that are too large!

# %%
# %%bash
# ## Before proceeding on from here, realize that we will be pulling in some pretty large models.
# ## Please run the following command to see how much space you're using with your current set of models.
# du -sch /root/.cache/huggingface/hub/*
#
# ## If your bottom number (folder total) over 200GB, please rm -rf the models you no longer need
# rm -rf /root/.cache/huggingface/hub/*
# rm -rf /root/.cache/huggingface/hub/tmp*  #<- not important
# Out:
# 419M	/root/.cache/huggingface/hub/models--BAAI--bge-base-en-v1.5
# 479M	/root/.cache/huggingface/hub/models--SamLowe--roberta-base-go_emotions
# 421M	/root/.cache/huggingface/hub/models--bert-base-uncased
# 475M	/root/.cache/huggingface/hub/models--deepset--roberta-base-squad2
# 1.6G	/root/.cache/huggingface/hub/models--facebook--bart-large-mnli
# 3.0G	/root/.cache/huggingface/hub/models--google--flan-t5-large
# 526M	/root/.cache/huggingface/hub/models--gpt2
# 479M	/root/.cache/huggingface/hub/models--nicholasKluge--ToxicityModel
# 940M	/root/.cache/huggingface/hub/models--nlpconnect--vit-gpt2-image-captioning
# 581M	/root/.cache/huggingface/hub/models--openai--clip-vit-base-patch32
# 282M	/root/.cache/huggingface/hub/models--openai--whisper-base
# 5.8G	/root/.cache/huggingface/hub/models--openai--whisper-large-v2
# 6.7G	/root/.cache/huggingface/hub/models--stabilityai--stable-diffusion-xl-base-1.0
# 853M	/root/.cache/huggingface/hub/models--t5-base
# ...

# %% [markdown]
# ### A7. Training Data
#
# Regardless of the license under which a model is offered, do remember that these models are always trained on data sources. The use of said data sources may or may not subscribe to your standard of ethics or may have its own licensing that should be considered (and might be overlooked by some model developers). It should always be a point of consideration for you to track down the source of data and consider whether it can pose a risk to your use cases (especially in commercial situations where you try to incorporate the models into a larger pipeline).

# %% [markdown]
# <center><a href="https://www.nvidia.com/en-us/training/"><img src="https://dli-lms.s3.amazonaws.com/assets/general/DLI_Header_White.png" width="400" height="186" /></a></center>
